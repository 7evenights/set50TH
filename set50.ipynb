# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
url = "https://marketdata.set.or.th/mkt/sectorquotation.do?sector=SET50&language=th&country=TH"

# %%
r = requests.get(url)

# %%
html_page = BeautifulSoup(r.text, "html.parser")
# Out:
# <!DOCTYPE html>
#
# <html lang="th">
# <!--[if lt IE 7]> <html class="no-js lt-ie9 lt-ie8 lt-ie7" lang="th"> <![endif]-->
# <!--[if IE 7]> <html class="no-js lt-ie9 lt-ie8" lang="th"> <![endif]-->
# <!--[if IE 8]> <html class="no-js lt-ie9" lang="th"> <![endif]-->
# <!--[if gt IE 8]><!--> <html class="no-js" lang="th"> <!--<![endif]-->
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge,chrome=1,IE=8" http-equiv="X-UA-Compatible"/>
# <meta content="The Stock Exchange of Thailand: Your Investment Resource for Thailand's Capital Market" name="description"/>
# <meta content="SET, mai, thai stocks, Thailand, stock, stock exchange, Thai capital market, equity, bond, derivatives, stock market, quotes, financial, internet trading, listed companies, IPO, regulations, broker, market data, investment information, news, investor education" name="keywords"/>
# <meta content="width=device-width, initial-scale=1, user-scalable=yes" name="viewport"/>
# <title>ตลาดหลักทรัพย์แห่งประเทศไทย - ราคาหลักทรัพย์ - ดัชนี SET50</title>
# <link href="/images/favicon.ico" rel="shortcut icon" type="image/vnd.microsoft.icon"/>
# <link href="/styles/bootstrap.min.css" rel="stylesheet"/>
# <link href="/styles/bootstrap-theme.min.css" rel="stylesheet"/>
# <link href="/styles/font-awesome.min.css" rel="stylesheet"/>
# <link href="/styles/bootstrap-submenu.min.css" rel="stylesheet"/>
# <link href="/styles/main.css" rel="stylesheet"/>
# <link href="/styles/main-en.css" rel="stylesheet"/>
# <link href="/styles/setstyle.css" rel="stylesheet"/>
# <link href="/styles/main-responsive.css" rel="stylesheet"/>
# <link href="/styles/tablet.css" rel="stylesheet"/>
# <link href="/scripts/fullcalendar-2.1.1/fullcalendar.min.css" rel="stylesheet"/>
# <!--[if lt IE 10]><link rel="stylesheet" href="/styles/ie.css"> <![endif]-->
# <script src="/scripts/vendor/jquery.min.js"></script>
# <!-- Start Other CSS -->
# <!-- Start Chart CSS -->
# <link href="/styles/chart.css" rel="stylesheet"/>
# <!-- End Chart CSS -->
# <!-- End Other CSS -->
# <!--[if lt IE 9]>
#     <script src="/scripts/vendor/html5shiv.min.js"></script>
#     <script src="/scripts/vendor/modernizr-2.6.2-respond-1.1.0.min.js"></script>
#     <![endif]-->
# <!-- Facebook Pixel Code -->
# <script>
# 	!function(f,b,e,v,n,t,s){if(f.fbq)return;n=f.fbq=function(){n.callMethod?
# 			n.callMethod.apply(n,arguments):n.queue.push(arguments)};if(!f._fbq)f._fbq=n;
# 		n.push=n;n.loaded=!0;n.version='2.0';n.queue=[];t=b.createElement(e);t.async=!0;
# 		t.src=v;s=b.getElementsByTagName(e)[0];s.parentNode.insertBefore(t,s)}(window,
# 			document,'script','https://connect.facebook.net/en_US/fbevents.js');
#
# 	fbq('init', '1613758345606983');
# 	fbq('track', "PageView");
# </script>
# <noscript><img height="1" src="https://www.facebook.com/tr?id=1613758345606983&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/></noscript>
# <script>
#   !function(f,b,e,v,n,t,s)
#   {if(f.fbq)return;n=f.fbq=function(){n.callMethod?
#   n.callMethod.apply(n,arguments):n.queue.push(arguments)};
#   if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0';
#   n.queue=[];t=b.createElement(e);t.async=!0;
#   t.src=v;s=b.getElementsByTagName(e)[0];
#   s.parentNode.insertBefore(t,s)}(window, document,'script',
#   'https://connect.facebook.net/en_US/fbevents.js');
#   fbq('init', '226880918049905');
#   fbq('track', 'PageView');
# </script>
# <noscript><img height="1" src="https://www.facebook.com/tr?id=226880918049905&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/></noscript>
# <!-- TSI 18/06/2018 - 31/12/2018 -->
# <script>
#   !function(f,b,e,v,n,t,s)
#   {if(f.fbq)return;n=f.fbq=function(){n.callMethod?
#   n.callMethod.apply(n,arguments):n.queue.push(arguments)};
#   if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0';
#   n.queue=[];t=b.createElement(e);t.async=!0;
#   t.src=v;s=b.getElementsByTagName(e)[0];
#   s.parentNode.insertBefore(t,s)}(window, document,'script',
#   'https://connect.facebook.net/en_US/fbevents.js');
#   fbq('init', '171385340201265');
#   fbq('track', 'PageView');
# </script>
# <noscript><img height="1" src="https://www.facebook.com/tr?id=171385340201265&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/></noscript>
# <!-- End Facebook Pixel Code -->
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-M3TXWD9');</script>
# <!-- End Google Tag Manager -->
# <script src="/scripts/pdpa-script.js"></script>
# </head>
# <body>
# <!-- Google Tag Manager (noscript) -->
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-M3TXWD9" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) -->
# <!--[if lt IE 7]>
# <p class="browsehappy">You are using an <strong>outdated</strong> browser. Please <a href="http://browsehappy.com/">upgrade your browser</a> to improve your experience.</p>
# <![endif]-->
# <!-- Start header -->
# <div class="webonly">
# <!-- Start header -->
# <div class="container mobile-language-selector collapse" id="mobile-language-sel">
# <p class="pull-left"><strong>Language :</strong></p>
# <ul class="pull-right">
# <li><a href="localeswitching.do?language=th&amp;country=TH&amp;nextpage=http%3A%2F%2Fmarketdata.set.or.th%2Fmkt%2Fsectorquotation.do%3Fsector%3DSET50">ไทย</a></li>
# <li class="last-item"><a href="localeswitching.do?language=en&amp;country=US&amp;nextpage=http%3A%2F%2Fmarketdata.set.or.th%2Fmkt%2Fsectorquotation.do%3Fsector%3DSET50">EN</a></li>
# </ul>
# </div>
# <div class="header" id="header">
# <div class="container logo_banner">
# <div class="row">
# <div class="col-xs-12 col-md-2 col-sm-4 logo_header">
# <a class="logo-set-th" href="https://www.set.or.th/th/index.html"></a>
# <ul class="pull-right mini-language-menu visible-xs">
# <li><a class="btn btn-link btn-mobile-toggle-language" data-target="#mobile-language-sel" data-toggle="collapse" href="#">Language</a></li>
# <li><a class="btn btn-link btn-mobile-signin" data-target="#login-box" data-toggle="collapse" href="#">ลงชื่อเข้าใช้</a></li>
# </ul>
# </div>
# <div class="col-xs-12 col-sm-8 col-md-10 braner-and-search padding-0">
# <!-- Top Banner area -->
# <div class="visible-lg braner-header">
# <!-- Start dfp code -->
# <script type="text/javascript">
# var googletag = googletag || {};
# googletag.cmd = googletag.cmd || [];
# (function () {
#     var gads = document.createElement('script');
#     gads.async = true;
#     gads.type = 'text/javascript';
#     var useSSL = 'https:' == document.location.protocol;
#     gads.src = (useSSL ? 'https:' : 'http:') +
#         '//www.googletagservices.com/tag/js/gpt.js';
#     var node = document.getElementsByTagName('script')[0];
#     node.parentNode.insertBefore(gads, node);
# })();
# </script>
# <script type="text/javascript">
# googletag.cmd.push(function () {
#     googletag.defineSlot('/15511860/SET_TH_top_banner_728x90', [728, 90], 'div-gpt-ad-1330935727550-0').addService(googletag.pubads());
#     googletag.pubads().enableSingleRequest();
#     googletag.enableServices();
# });
# </script>
# <!-- End dfp code -->
# <!-- SET_TH_top_banner_728x90 -->
# <div class="personalized-top-banner-optimize" style="display: none;">
# <a href="#" target="_blank"><img src="#" style="width:100%;"/></a>
# </div>
# <div class="personalized-top-banner" style="display:none;">
# <div id="div-gpt-ad-1330935727550-0" style="width:728px; height:90px;">
# <script type="text/javascript">googletag.cmd.push(function() { googletag.display('div-gpt-ad-1330935727550-0'); });</script>
# </div>
# </div>
# </div>
# <div class="search_header navbar-collapse collapse" id="nav-form-search">
# <form action="https://www.set.or.th/commons/searchresult.html" class="form-search" id="cse-search-box" role="form" target="_blank">
# <input name="cx" type="hidden" value="partner-pub-0901699256947485:8450636272"/>
# <input name="cof" type="hidden" value="FORID:9"/>
# <input name="ie" type="hidden" value="UTF-8"/>
# <input name="sa" type="submit" value="ค้นหา"/>
# <div class="input-group">
# <input class="input-search form-control not_focus" name="q" placeholder="Search" type="text" value="Search"/>
# <span class="input-group-btn">
# <button class="btn btn-default btn-search" onclick="javascript:submit();" type="button"><i class="fa fa-search"></i></button>
# </span>
# </div>
# </form>
# <div class="row">
# <div class="col-md-12 search_lan_select hidden-xs">
#                 Language :
#                 <a href="localeswitching.do?language=th&amp;country=TH&amp;nextpage=http%3A%2F%2Fmarketdata.set.or.th%2Fmkt%2Fsectorquotation.do%3Fsector%3DSET50">ไทย</a> |
#
#
#                     <a href="localeswitching.do?language=en&amp;country=US&amp;nextpage=http%3A%2F%2Fmarketdata.set.or.th%2Fmkt%2Fsectorquotation.do%3Fsector%3DSET50">EN</a>
#
#
#
#                 <div class="sr-only"></div>
# <div class="pull-right"><a class="printer-th" href="#" onclick="window.print();" title="พิมพ์หน้านี้"></a></div>
# </div>
# </div>
# </div>
# <div class="nav-get-f visible-xs visible-sm clearfix">
# <form action="" onsubmit="quoteActionGotoPage();return false;" role="search">
# <div class="pull-left">
# <input id="txtSymbolXS" placeholder="Get Quote" type="text" value="Get Quote"/>
# </div>
# <div class="pull-right">
# <button class="btn-search" id="searchBtnXS" onclick="quoteActionGotoPage();" type="button"><i class="fa fa-caret-right"></i></button>
# <button id="quoteBtn2" onclick="window.location='https://www.set.or.th/set/commonslookup.do?language=th&amp;country=TH';" type="button">
# <small>
#                     ชื่อย่อ
#                   </small>
# </button>
# </div>
# </form>
# </div>
# </div>
# </div>
# </div>
# <!-- Start Nav header -->
# <nav class="navbar border-bottom-yellow-4" id="top-nav" role="navigation">
# <div class="container">
# <div class="row background-nav-tablet">
# <div class="navbar-header">
# <button class="navbar-toggle collapsed navbar-toggle-show" data-target="#nav-header" data-toggle="collapse" type="button">
# <div class="icon-container">
# <span class="sr-only">Toggle navigation</span>
# <span class="icon-bar icon-bar-menu"></span>
# <span class="icon-bar icon-bar-menu"></span>
# <span class="icon-bar icon-bar-menu"></span>
# </div>
# <span class="icon-text">MENU</span>
# </button>
# <button class="btn btn-link btn-toggle-search visible-xs" data-target="#nav-form-search" data-toggle="collapse" type="button">
# <i class="fa fa-search"></i>
# </button>
# <a class="navbar-brand" href="https://www.set.or.th/th/index.html"></a>
# </div>
# <!-- Collect the nav links, forms, and other content for toggling -->
# <div class="collapse navbar-collapse padding-right-0" id="nav-header">
# <ul class="nav navbar-nav">
# <li class="nav1 dropdown dropdown-nav"><a class="dropdown-toggle" data-hover="dropdown" data-toggle="dropdown" href="https://www.set.or.th/th/about/index.html"><span class="visible-xs visible-sm">เกี่ยวกับตลท.</span></a>
# <ul class="dropdown-menu dropdown-nav-ul">
# <li><a href="https://www.set.or.th/th/about/vision/vision_p1.html">พันธกิจและวิสัยทัศน์</a></li>
# <li class="dropdown-submenu"><a aria-expanded="false" data-toggle="dropdown" href="https://www.set.or.th/th/about/overview/history_p1.html">ภาพรวม ตลท.</a>
# <ul class="dropdown-menu popover-set navtop" role="menu">
# <li><a href="https://www.set.or.th/th/about/overview/history_p1.html">ประวัติและบทบาท</a></li>
# <li><a href="https://www.set.or.th/th/about/overview/board_p1.html">คณะกรรมการ</a></li>
# <li><a href="https://www.set.or.th/th/about/overview/organization_p1.html">คณะผู้บริหาร/โครงสร้าง</a></li>
# <li><a href="https://www.set.or.th/th/about/overview/setlogo_p1.html">ตราสัญลักษณ์ ตลท.</a></li>
# <li><a href="https://www.set.or.th/th/about/overview/setgroup_p1.html">กลุ่มตลาดหลักทรัพย์ฯและโครงสร้างการถือหุ้น</a></li>
# <!--<li><a href="https://www.set.or.th/th/about/overview/share_p1.html">โครงสร้างการถือหุ้น</a></li>-->
# <li><a href="https://www.set.or.th/th/about/overview/setcg_p1.html">การกำกับดูแลกิจการที่ดี</a></li>
# <li><a href="https://www.set.or.th/th/about/overview/whistleblowing_p1.html">การแจ้งเบาะแส</a></li>
# <li><a href="http://www.tfex.co.th/th/about/glance.html" target="_blank">เกี่ยวกับตลาดสัญญาซื้อขายล่วงหน้า</a></li>
# </ul>
# </li>
# <li class="dropdown-submenu"><a aria-expanded="false" data-toggle="dropdown" href="https://www.set.or.th/th/about/annual/annual_p1.html">รายงานผลการดำเนินงาน</a>
# <ul class="dropdown-menu popover-set navtop" role="menu">
# <li><a href="https://www.set.or.th/th/about/annual/annual_p1.html">รายงานประจำปี</a></li>
# <li><a href="https://www.set.or.th/th/about/annual/sd_report_p1.html">รายงานความยั่งยืน</a></li>
# <li><a href="https://www.set.or.th/th/about/annual/financial_statement_p1.html">งบการเงินประจำปีและ MD&amp;A</a></li>
# </ul>
# </li>
# <li><a href="https://www.set.or.th/set/holiday.do?language=th&amp;country=TH">วันหยุดตลาดหลักทรัพย์</a></li>
# <li class="dropdown-submenu"><a aria-expanded="false" data-toggle="dropdown" href="https
li class="dropdown-submenu"><a aria-expanded="false" data-toggle="dropdown" href="https://www.set.or.th/th/regulations/tax/tax_p1.html">ภาษี</a>
# 		<ul class="dropdown-menu popover-set navtop" role="menu">
# 			<li><a href="https://www.set.or.th/th/regulations/tax/tax_p1.html">ตราสารทุน</a></li>
# 			<li><a href="https://www.set.or.th/th/regulations/tax/tax_bond_p1.html">ตราสารหนี้</a></li>
# 		</ul>
# 		</li>-->
# <li><a href="https://www.set.or.th/th/regulations/protection/protection_p1.html">การคุ้มครองผู้ลงทุน</a></li>
# <li><a href="https://www.set.or.th/th/regulations/consult/market_consultation_p1.html">Market Consultation </a></li>
# <li class="dropdown-submenu">
# <a aria-expanded="false" data-toggle="dropdown" href="https://www.set.or.th/set/regulatorystatistics.do?language=th&amp;country=TH">ค่าสถิติงานกำกับ</a>
# <ul class="dropdown-menu popover-set navtop" role="menu">
# <li><a href="https://www.set.or.th/set/regulatorystatistics.do?language=th&amp;country=TH">ค่าสถิติงานกำกับ</a></li>
# <li><a href="https://www.set.or.th/th/regulations/statistics/causes_statistics_p1.html">สาเหตุการขึ้นเครื่องหมาย SP ปี 2560 และปี 2561</a></li>
# </ul>
# </li>
# </ul>
# </li>
# <li class="nav3 dropdown dropdown-nav"><a class="dropdown-toggle" data-hover="dropdown" data-toggle="dropdown" href="https://www.set.or.th/th/products/index.html"><span class="visible-xs visible-sm">สินค้า/บริการ</span></a>
# <ul class="dropdown-menu dropdown-nav-ul">
# <li class="dropdown-submenu"><a aria-expanded="false" data-toggle="dropdown" href="https://www.set.or.th/th/products/index/setindex_p1.html">ดัชนี</a>
# <ul class="dropdown-menu popover-set navtop" role="menu">
# <li><a href="https://www.set.or.th/th/products/index/setindex_p1.html">ดัชนีตลาดหลักทรัพย์</a></li>
# <li><a href="https://www.set.or.th/th/products/index/maiindex_p1.html">ดัชนี mai</a></li>
# <li><a href="https://www.set.or.th/th/products/index/ftse_set_p1.html">ดัชนี FTSE SET </a></li>
# <li><a href="https://www.set.or.th/th/products/index/ftse_asean_p1.html">ดัชนี FTSE ASEAN</a></li>
# <li><a href="https://www.set.or.th/th/products/index/tri_p1.html">ดัชนีผลตอบแทนรวม (TRI)</a></li>
# </ul>
# </li>
# <li><a href="https://www.set.or.th/th/products/equities/equities_p1.html">ตราสารทุน</a></li>
# <!--<li><a href="https://www.set.or.th/th/products/bonds/bonds_p1.html">ตราสารหนี้</a></li>-->
# <li><a href="http://www.tfex.co.th/th/products/products.html" target="_blank">ตราสารอนุพันธ์</a></li>
# <li><a href="https://www.set.or.th/set/etfstatistics.do?language=th&amp;country=TH">อีทีเอฟ (ETF)</a></li>
# <li class="dropdown-submenu">
# <a aria-expanded="false" data-toggle="dropdown" href="https://www.set.or.th/set/education/html.do?name=mutualfund&amp;showTitle=F">กองทุนรวม</a>
# <ul class="dropdown-menu popover-set navtop" role="menu">
# <li><a href="https://www.set.or.th/set/education/html.do?name=mutualfund&amp;showTitle=F" target="_blank">Thai Mutual Fund</a></li>
# <li><a href="/th/products/fund/cg_fund.html">CG Fund</a></li>
# </ul>
# </li>
# <li><a href="https://www.set.or.th/site/products/dw?lang=th" target="_blank">ใบสำคัญแสดงสิทธิอนุพันธ์ (DW)</a></li>
# <li class="dropdown-submenu">
# <a aria-expanded="false" data-toggle="dropdown" href="/th/products/dr/dr_knowledge.html">ตราสารแสดงสิทธิการฝากหลักทรัพย์ต่างประเทศ (DR)</a>
# <ul class="dropdown-menu popover-set navtop" role="menu">
# <li><a href="https
a>
# <ul class="dropdown-menu popover-set navtop" role="menu">
# <li><a href="https://www.set.or.th/set/memberlist.do?language=th&amp;country=TH">รายชื่อบริษัทสมาชิกตลาดหลักทรัพย์แห่งประเทศไทย</a></li>
# <!--<li><a href="https://www.set.or.th/th/products/member/firsts/firsts_dealer_p1.html">รายชื่อผู้ค้าตราสารหนี้ในระบบ Firsts</a></li>-->
# <li><a href="https://www.set.or.th/th/products/member/firsts/firsts_investor_p1.html">รายชื่อผู้ลงทุนสถาบันในระบบ Firsts</a></li>
# <li><a href="http://www.tfex.co.th/th/member/list.html" target="_blank">รายชื่อบริษัทสมาชิกตลาดสัญญาซื้อขายล่วงหน้า</a></li>
# <li><a href="https://www.set.or.th/th/products/member/member_stock.html">การรับสมาชิก</a></li>
# </ul>
# </li>
# <li><a href="https://www.set.or.th/th/products/isv/isv_p1.html">บริษัทผู้พัฒนาระบบ (ISV)</a></li>
# <li class="dropdown-submenu"><a aria-expanded="false" data-toggle="dropdown" href="https://www.set.or.th/th/setapp.html">SET App</a>
# <ul class="dropdown-menu popover-set navtop" role="menu">
# <li><a href="https://www.set.or.th/th/setapp.html">ดาวน์โหลด</a></li>
# <li><a href="https://www.set.or.th/th/setapp_noti.html">การตั้งค่า Notifications</a></li>
# </ul>
# </li>
# <li class="dropdown-submenu"><a aria-expanded="false" data-toggle="dropdown" href="https://www.set.or.th/th/socialmedia/all.html">SET Social Media</a>
# <ul class="dropdown-menu popover-set navtop" role="menu">
# <li><a href="https://www.set.or.th/th/socialmedia/all.html">ทั้งหมด</a></li>
# <li><a href="https://www.facebook.com/set.or.th" target="_blank">Facebook</a></li>
# <li><a href="https://www.messenger.com/t/set.or.th" target="_blank">Messenger</a></li>
# <li><a href="https://www.set.or.th/th/socialmedia/LINE.html">LINE</a></li>
# <li><a href="https://www.youtube.com/setthailand" target="_blank">Youtube</a></li>
# <li><a href="https://www.instagram.com/set_thailand/" target="_blank">Instagram</a></li>
# <li><a href="https://twitter.com/set_thailand" target="_blank">Twitter</a></li>
# </ul>
# </li>
# <li><a href="https://www.set.or.th/th/products/financial/financial_instruments.html">เครื่องมือทางการเงิน</a></li>
# <li class="dropdown-submenu"><a aria-expanded="false" data-toggle="dropdown" href="https://www.set.or.th/th/products/resource/resource_p1.html">แหล่งศึกษาข้อมูล</a>
# <ul class="dropdown-menu popover-set navtop" role="menu">
# <li><a href="https://www.set.or.th/th/products/resource/resource_p1.html">แหล่งความรู้การลงทุน</a></li>
# <li><a href="https://www.set.or.th/setresearch/setresearch.html" target="_blank">SET Research</a></li>
# <li><a href="https://www.set.or.th/th/market/MnA.html">การควบรวมกิจการ</a></li>
# </ul>
# </li>
# <li class="dropdown-submenu">
# <a aria-expanded="false" data-toggle="dropdown" href="https://www.set.or.th/th/setresearch/setresearch_p1.html">SET Research</a>
# <ul class="dropdown-menu popover-set navtop" role="menu">
# <li><a href="https://www.set.or.th/th/setresearch/setresearch_p1.html">SET Research</a></li>
# <li><a href="https://www.set.or.th/th/setresearch/database/overview.html">Database</a></li>
# <li><a href="https://www.set.or.th/th/setresearch/information/press_release.html">Information</a></li>
# <li><a href="https://www.set.or.th/th/setresearch/research/research_paper.html">Research</a></li>
# <li><a href="https://www.set.or.th/th/setresearch/events/forum.html">Events</a></li>
# <li><a href="https://www.set.or.th/ICMC/index.html" target="_blank">ICMC</a></li>
# <li><a href="https://www.set.or.th/th/setresearch/sentiment_indices/sentiment_indices.html">Sentiment Indices</a></li>
# <li><a href="https://www.set.or.th/th/setresearch/grant/research_grant.html">Research Grant</a></li>
# </ul>
# </li>
# </ul>
# </li>
# <li class="nav4 dropdown dropdown-nav"><a class="dropdown-toggle" data-hover="dropdown" data-toggle="dropdown" href="https://marketdata.set.or.th/mkt/sectorialindices.do?language=th&amp;country=TH"><span class="visible-xs visible-sm">ข้อมูลการซื้อขาย</span></a>
# <ul class="dropdown-menu dropdown-nav-ul">
# <li class="dropdown-submenu"><a aria-expanded="false" data-toggle="dropdown" href="https://marketdata.set.or.th/mkt/sectorialindices.do?language=th&amp;country=TH">ดัชนี</a>
# <ul class="dropdown-menu popover-set navtop" role="menu">
# <li><a href="https://marketdata.set.or.th/mkt/sectorialindices.do?language=th&amp;country=TH">ราคาดัชนีตลาดหลักทรัพย์</a></li>
# <li><a href="https://marketdata.set.or.th/mkt/ftsesetindex.do?language=th&amp;country=TH">ราคาดัชนี FTSE SET Series</a></li>
# <li><a href="https://www.set.or.th/th/market/setindexchart.html">กราฟราคาดัชนีย้อนหลัง</a></li>
# <li><a href="https://www.set.or.th/th/market/ftse_asean.html">ราคาดัชนี FTSE ASEAN</a></li>
# <li><a href="https://www.set.or.th/th/market/constituents.html">รายชื่อหลักทรัพย์ที่ใช้คำนวณดัชนี</a></li>
# <li><a href="https://www.set.or.th/th/market/tri.html">ราคาดัชนีผลตอบแทนรวม (TRI)</a></li>
# <li><a href="https://www.set.or.th/th/market/market_statistics.html">สถิติดัชนีตลาดหลักทรัพย์</a></li>
# </ul>
# </li>
# <li class="dropdown-submenu"><a aria-expanded="false" data-toggle="dropdown" href="https://marketdata.set.or.th/mkt/marketsummary.do?language=th&amp;country=TH">ตราสารทุน</a>
# <ul class="dropdown-menu popover-set navtop" role="menu">
# <li><a href="https://marketdata.set.or.th/mkt/marketsummary.do?language=th&amp;country=TH">สรุปภาพรวมตลาด</a></li>
# <li><a href="https://marketdata.set.or.th/mkt/sectorquotation.do?sector=SET50&amp;language=th&amp;country=TH">ราคาหลักทรัพย์</a></li>
# <li><a href="https://marketdata.set.or.th/mkt/topten.do?language=th&amp;country=TH">สิบอันดับหลักทรัพย์</a></li>
# <li><a href="https://www.set.or.th/th/market/foreign_currency_indicative_stock_quote.html">Foreign Currency Indicative Stock Quote</a></li>
# <li><a href="https://www.set.or.th/set/nvdroverview.do?language=th&amp;country=TH">ข้อมูล NVDR</a></li>
# <li><a href="https://www.set.or.th/set/shortsales.do?language=th&amp;country=TH">ข้อมูลธุรกรรมขายชอร์ต</a></li>
# <li><a href="https://marketdata.set.or.th/mkt/fivedays.do?language=th&amp;country=TH">สรุปมูลค่าการซื้อขาย 5 วันทำการล่าสุด</a></li>
# <li><a href="https://marketdata.set.or.th/mkt/investortype.do?language=th&amp;country=TH">สรุปมูลค่าการซื้อขายตามกลุ่มนักลงทุน</a></li>
# </ul>
# </li>
# <li class="dropdown-submenu"><a aria-expanded="false" data-toggle="dropdown" href="https://marketdata.set.or.th/tfx/tfexoverview.do?locale=th_TH">ตราสารอนุพันธ์</a>
# <ul class="dropdown-menu popover-set navtop" role="menu">
# <li><a href="https://marketdata.set.or.th/tfx/tfexoverview.do?locale=th_TH">สรุปภาพรวมตลาด</a></li>
# <li><a href="https://marketdata.set.or.th/tfx/tfexintradayreport.do?locale=th_TH">ราคาอนุพันธ์</a></li>
# <li><a href="https://marketdata.set.or.th/tfx/tfexblocktradereport.do?locale=th_TH">ข้อมูลการซื้อขายรายใหญ่ (Block Trade)</a></li>
# <li><a href="https://marketdata.set.or.th/tfx/tfexinvestortypetrading.do?locale=th_TH">สรุปปริมาณซื้อขายตามกลุ่มนักลงทุน</a></li>
# <li><a href="https://marketdata.set.or.th/tfx/tfexhistoricalreport.do?locale=th_TH">ข้อมูลการซื้อขายย้อนหลัง</a></li>
# <li><a href="http://www.tfex.co.th/th/marketdata/sf_blocktrade_report.html" target="_blank">สถิติการซื้อขายรายใหญ่ (Stock Futures Block Trade Report)</a></li>
# <li><a href="https://marketdata.set.or.th/tfx/tfexbrokerrank.do?locale=th_TH">อันดับการซื้อขายของบริษัทสมาชิก </a></li>
# <li><a href="http://www.tfex.co.th/tfex/referenceData.html?locale=th_TH" target="_blank">ข้อมูลอ้างอิง</a></li>
# <li><a href="http://www.tfex.co.th/tfex/downloadSeriesProfile.html" target="_blank">ดาวน์โหลด Series Profile</a></li>
# </ul>
# </li>
# <!--<li class="dropdown-submenu"><a aria-expanded="false" data-toggle="dropdown" href="https://marketdata.set.or.th/tfx/bexoverview.do?locale=th_TH">ตราสารหนี้</a>
# 		<ul class="dropdown-menu popover-set navtop" role="menu">
# 			<li><a href="https://marketdata.set.or.th/tfx/bexoverview.do?locale=th_TH">สรุปภาพรวมตลาด</a></li>
# 			<li><a href="https://marketdata.set.or.th/tfx/bexgovbondyield.do?locale=th_TH">อัตราผลตอบแทนพันธบัตรรัฐบาลระหว่างวัน</a></li>
# 			<li><a href="https://marketdata.set.or.th/tfx/bexquotationbyissuer.do?locale=th_TH">ราคาตราสารหนี้ (AOM)</a></li>
# 			<li><a href="https://marketdata.set.or.th/tfx/bexdealerquote.do?locale=th_TH">ราคาเสนอซื้อ-ขาย ของ Dealer</a></li>
# 			<li><a href="https://marketdata.set.or.th/tfx/bexhistoricaldata.do?locale=th_TH">ข้อมูลการซื้อขายย้อนหลัง </a></li>
# 			<li><a href="https://marketdata.set.or.th/tfx/bexinterestrate.do?locale=th_TH">อัตราอ้างอิง</a></li>
# 			<li><a href="https://marketdata.set.or.th/tfx/bexcreditrating.do?locale=th_TH">อันดับเครดิต</a></li>
# 			<li><a href="https://www.settrade.com/C03_05_bond_Calculator.jsp" target="_blank">เครื่องคำนวณตราสารหนี้</a></li>
# 		</ul>
# 		</li>-->
# <li><a href="https://www.set.or.th/th/market/market_statistics.html">สถิติสำคัญของตลาดหลักทรัพย์</a></li>
# </ul>
# </li>
# <li class="nav5 dropdown dropdown-nav"><a class="dropdown-toggle" data-hover="dropdown" data-toggle="dropdown" href="https://www.set.or.th/set/searchtodaynews.do?source=company&amp;symbol=&amp;securityType=S&amp;newsGroupId=&amp;headline=&amp;submit=%E0%B8%84%E0%B9%89%E0%B8%99%E0%B8%AB%E0%B8%B2&amp;language=th&amp;country=TH"><span class="visible-xs visible-sm">ข้อมูลบริษัท/หลักทรัพย์</span></a>
# <ul class="dropdown-menu dropdown-nav-ul">
# <li class="dropdown-submenu"><a aria-expanded="false" data-toggle="dropdown" href="https://www.set.or.th/set/searchtodaynews.do?source=company&amp;symbol=&amp;securityType=S&amp;newsGroupId=&amp;headline=&amp;submit=%E0%B8%84%E0%B9%89%E0%B8%99%E0%B8%AB%E0%B8%B2&amp;language=th&amp;country=TH">ข่าวบริษัท/หลักทรัพย์</a>
# <ul class="dropdown-menu popover-set navtop" role="menu">
# <li><a href="https://www.set.or.th/set/searchtodaynews.do?source=company&amp;symbol=&amp;securityType=S&amp;newsGroupId=&amp;headline=&amp;submit=%E0%B8%84%E0%B9%89%E0%B8%99%E0%B8%AB%E0%B8%B2&amp;language=th&amp;country=TH">ข่าววันนี้ </a></li>
# <li><a href="https://www.set.or.th/set/newslistinput.do?language=th&amp;country=TH&amp;headline=">ข่าวย้อนหลัง </a></li>
# <li><a href="https://www.set.or.th/set/marketalertnews.do?language=th&amp;country=TH">Market Alerts </a></li>
# <li><a href="https://www.set.or.th/set/cashbalancesecurity.do?language=th&amp;country=TH">หลักทรัพย์ที่เข้าข่ายมาตรการกำกับการซื้อขาย</a></li>
# <li><a href="https://www.set.or.th/set/cautionsecurity.do?language=th&amp;country=TH">หลักทรัพย์ภายใต้เครื่องหมาย C (Caution)</a></li>
# <li><a href="https://www.set.or.th/set/cashbalancesummary.do?language=th&amp;country=TH">สรุปหลักทรัพย์ตามมาตรการกำกับการซื้อขาย / เครื่องหมาย C / ซื้อขายชั่วคราว</a></li>
# </ul>
# </li>
# <li class="dropdown-submenu"><a aria-expanded="false" data-toggle="dropdown" href="https://www.set.or.th/set/commonslookup.do?language=th&amp;country=TH">ตราสารทุน</a>
# <ul class="dropdown-menu popover-set navtop" role="menu">
# <li><a href="https://www.set.or.th/set/commonslookup.do?language=th&amp;country=TH">ข้อมูลรายบริษัท / หลักทรัพย์</a></li>
# <li><a href="https://www.set.or.th/set/xcalendar.do?language=th&amp;country=TH">ปฏิทินหลักทรัพย์ </a></li>
# <li><a href="https://www.set.or.th/th/company/ipo/upcoming_ipo_set.html">หลักทรัพย์ IPO</a></li>
# <li><a href="https://www.settrade.com/settrade/ipo/ipo-performance" target="_blank">IPO Performance</a></li>
# <li><a href="https://www.set.or.th/th/company/companylist.html">รายชื่อบริษัท / หลักทรัพย์</a></li>
# <li><a href="https://www.set.or.th/tsd/th/download/isin.html">เลขรหัสหลักทรัพย์สากล</a></li>
# <li><a href="https://www.set.or.th/set/concession.do?language=th&amp;country=TH">รายชื่อบริษัทที่รายงานว่าได้รับสัมปทานจากรัฐ</a></li>
# </ul>
# </li>
# <!--<li class="dropdown-submenu"><a aria-expanded="false" data-toggle="dropdown" href="https://marketdata.set.or.th/tfx/bondlookup.do?locale=th_TH">ตราสารหนี้</a>
# 		<ul class="dropdown-menu popover-set navtop" role="menu">
# 			<li><a href="https://marketdata.set.or.th/tfx/bondlookup.do?locale=th_TH">ข้อมูลรายตราสารหนี้</a></li>
# 			<li><a href="https://marketdata.set.or.th/tfx/bondcalendar.do?locale=th_TH">ปฏิทินตราสารหนี้</a></li>
# 			<li><a href="https://marketdata.set.or.th/tfx/bondoutstanding.do?locale=th_TH">สรุปมูลค่าคงค้าง</a></li>
# 			<li><a href="https://marketdata.set.or.th/tfx/bondlisting.do?locale=th_TH">ตราสารหนี้จดทะเบียนใหม่</a></li>
# 		</ul>
# 		</li>-->
# <li class="dropdown-submenu"><a aria-expanded="false" data-toggle="dropdown" href="https://www.set.or.th/streaming">Opportunity Day &amp; Company Highlights</a>
# <ul class="dropdown-menu popover-set navtop" role="menu">
# <li><a href="https://www.set.or.th/streaming">Opportunity Day</a></li>
# <li><a href="https://www.set.or.th/set/companysummary.do?language=th&amp;country=TH">สรุปข้อสนเทศบริษัทจดทะเบียน</a></li>
# <li><a href="https://www.set.or.th/th/company/document/document_p1.html">Stock Focus</a></li>
# </ul>
# </li>
# <li><a href="https://www.set.or.th/streaming/cupdate" target="_blank">C-Update</a></li>
# </ul>
# </li>
# <li class="nav6 dropdown dropdown-nav"><a class="dropdown-toggle" data-hover="dropdown" data-toggle="dropdown" href="https://www.set.or.th/mai/th/index.html"><span class="visible-xs visible-sm">หน่วยงาน</span></a>
# <ul class="dropdown-menu dropdown-nav-ul">
# <li class="dropdown-submenu"><a aria-expanded="false" data-toggle="dropdown" href="https://www.set.or.th/mai/th/index.html">ตลาด mai</a>
# <ul class="dropdown-menu popover-set navtop" role="menu">
# <li><a href="https://www.set.or.th/mai/th/about/vision.html">เกี่ยวกับ mai</a></li>
# <li><a href="https://portal.set.or.th/mai/notification.do?locale=th_TH">กฎเกณฑ์/กำกับ</a></li>
# <li><a href="https://portal.set.or.th/mai/todaynews.do?locale=th_TH">ข่าว</a></li>
# <li><a href="https://portal.set.or.th/mai/stocklistbytype.do?locale=th_TH">ข้อมูลการซื้อขาย</a></li>
# <li><a href="https://portal.set.or.th/mai/stockslookup.do?locale=th_TH">ข้อมูลบริษัทจดทะเบียน</a></li>
# <li><a href="https://www.set.or.th/th/products/listing2/listing_mai_p1.html">การเข้าจดทะเบียน/IPO</a></li>
# <li><a href="https://portal.set.or.th/mai/activitycontent.do?locale=th_TH&amp;categoryId=2">กิจกรรม</a></li>
# <li><a href="https://www.set.or.th/mai/th/mai_fund/mai_fund_p1.html">กองทุนที่ลงทุนใน mai</a></li>
# </ul>
# </li>
# <li class="dropdown-submenu"><a aria-expanded="false" data-toggle="dropdown" href="https://www.set.or.th/tch/th/index.html">สำนักหักบัญชี TCH</a>
# <ul class="dropdown-menu popover-set navtop" role="menu">
# <li><a href="https://www.set.or.th
class="dropdown-toggle" data-hover="dropdown" data-toggle="dropdown" href="https://www.set.or.th/set/newsrelease.do?language=th&amp;country=TH"><span class="visible-xs visible-sm">ข่าว/กิจกรรม</span></a>
# <ul class="dropdown-menu dropdown-nav-ul">
# <li><a href="https://www.set.or.th/set/newsrelease.do?language=th&amp;country=TH">News Release</a></li>
# <li><a href="http://portal.set.or.th/tsd/eventcalendar.html?locale=th_TH">ปฏิทินกิจกรรม</a></li>
# <li><a href="https://www.set.or.th/set/activityList.do?language=th&amp;country=TH&amp;categoryId=2">ภาพกิจกรรมบจ./ผู้ออกหลักทรัพย์</a></li>
# <li class="dropdown-submenu">
# <a aria-expanded="false" data-toggle="dropdown" href="https://www.set.or.th/set/iposhowcase.do?market=A&amp;language=th&amp;country=TH">กิจกรรมด้านผู้ออกหลักทรัพย์ </a>
# <ul class="dropdown-menu popover-set navtop" role="menu">
# <li><a href="https://www.set.or.th/set/iposhowcase.do?market=A&amp;language=th&amp;country=TH">เปิดตัวหุ้นใหม่ IPO</a></li>
# <li><a href="https://www.set.or.th/setawards">SET Awards</a></li>
# </ul>
# </li>
# <li class="dropdown-submenu">
# <a aria-expanded="false" data-toggle="dropdown" href="https://www.set.or.th/th/news/capital_market_innovation_awards/competition_p1.html">Capital Market Innovation Awards </a>
# <ul class="dropdown-menu popover-set navtop" role="menu">
# <li><a href="https://www.set.or.th/th/news/capital_market_innovation_awards/competition_p1.html">เกี่ยวกับโครงการ</a></li>
# <li><a href="https://www.set.or.th/th/news/capital_market_innovation_awards/20teams_p1.html">ประกาศผลงานเข้ารอบกลั่นกรอง</a></li>
# </ul>
# </li>
# <li><a href="https://www.set.or.th/th/news/cm_research_innovation/competition_p1.html">CM Research Innovation</a></li>
# <li><a href="https://www.set.or.th/thailandfocus/" target="_blank">Thailand Focus</a></li>
# <li class="dropdown-submenu">
# <a aria-expanded="false" data-toggle="dropdown" href="https://www.set.or.th/th/news/csr/csr_p1.html">ความรับผิดชอบต่อสังคม</a>
# <ul class="dropdown-menu popover-set navtop" role="menu">
# <li><a href="https://www.set.or.th/th/news/csr/social_recognition_project_p1.html">SET เชิดชูผู้ทำความดีเพื่อสังคม </a></li>
# </ul>
# </li>
# </ul>
# </li>
# </ul>
# <form class="navbar-form navbar-right nav-set-form" onsubmit="quoteActionGotoPage();return false;" role="search">
# <div class="nav-quote hidden-xs hidden-sm">
# <input id="txtSymbolLG" placeholder="Get Quote" type="text" value="Get Quote"/>
# <button class="btn-search" id="searchBtnLG" onclick=" quoteActionGotoPage();" type="button"><i class="fa fa-search"></i></button>
# <button id="quoteBtn" onclick="window.location='https://www.set.or.th/set/commonslookup.do?language=th&amp;country=TH';" type="button">
# <small>หาชื่อย่อ</small>
# </button>
# </div>
# </form>
# </div>
# <!-- end navbar-collapse -->
# </div>
# </div>
# </nav>
# <!-- End Nav header -->
# <!-- Start Forgot Password -->
# <div class="calendar-detail modal fade" id="frgtPasswordModal">
# <div class="modal-dialog modal-lg">
# <div class="modal-content" id="frgtPassword">
#
#         </div>
# </div>
# </div>
# <!-- End Forgot Password -->
# <div class="container row-text-login">
# <div class="row">
# <div>
# <div class="text-slide" id="breadcrumbs"></div>
# <div class="login-header navbar-collapse collapse" id="login-box">
# <form action="https://member.set.or.th/set/signinpage.do" id="loginForm" method="post" name="loginForm">
# <div class="login-box-container" id="loginBox">
# <h4 class="visible-xs"></h4>
# <input class="input-text-login" name="txtLogin" placeholder="E-mail or Username" type="text" value="E-mail or Username"/>
# <input class="input-text-login" name="txtPassword" placeholder="Password" type="password" value="Password"/>
# <input name="txtRtrPage" type="hidden" value="memberFirstPage"/>
# <input name="language" type="hidden" value="th">
# <input name="country" type="hidden" value="TH">
# <input class="btn-set btn-set-gray" type="submit" value="ลงชื่อเข้าใช้"/>
# <div class="login-register">
# <a href="https://member.set.or.th/set-member/#/registration?system=SET&amp;language=th" style="margin-right:4px;">สมัครสมาชิก</a>
# <a href="https://member.set.or.th/set-member/#/forgot-password?system=SET&amp;language=th" target="_blank">ลืมรหัสผ่าน</a>
# <div class="checkbox" style="margin-top: -1px;">
# <label><input checked="checked" name="txtKeepMe" style="margin-top: 3px" type="checkbox" value="1"/>ให้ฉันอยู่ในระบบ</label>
# </div>
# </div>
# <div class="facebook-login-register"><a href="javascript:facebookLogin();"><img class="facebook-login-img" src="/images/social_media/social-facebook-small-icon.png"/></a></div>
# </input></input></div>
# </form>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="clearfix"></div>
# </div>
# <div class="printonly"><img src="/images/logo_en.jpg"/></div>
# <!-- End header -->
# <div class="container">
# <div class="row sidebar-body-content">
# <!-- Start Sidebar -->
# <div class="webonly col-xs-12 col-md-2 sidebar-bg" id="sidebar-wrapper">
# <div id="sidebar">
# <div aria-multiselectable="true" class="panel-group" id="accordion" role="tablist"></div>
# <div class="tap-sign inward visible-xs visible-sm"><a class="btn-tap-sidebar" href="#"></a></div>
# </div>
# </div>
# <!-- End Sidebar -->
# <!-- Start Body -->
# <div class="col-xs-12 col-md-10" id="body-content">
# <div class="top-banner-nonweb" style="display: none;">
# <div class="visible-md visible-sm">
# <a href="https://setga.page.link/KabU5E4h39ihy9dh7" target="_blank"><img src="https://www.set.or.th/commons/img/banner/650x80_LINE_realtimequote.jpg"/></a>
# </div>
# <div class="visible-xs">
# <a href="https://setga.page.link/KabU5E4h39ihy9dh7" target="_blank"><img src="https://www.set.or.th/commons/img/banner/350x43_LINE_realtimequote.jpg"/></a>
# </div>
# </div>
# <div class="row">
# <div class="col-lg-12" id="maincontent">
# <div class="row">
# <h1 class="page-header underline-orange">ราคาหลักทรัพย์ - ดัชนี SET50</h1>
# <p class="content">
# <div class="row">
# <div class="col-xs-12 col-md-12 col-lg-12">
# <div class="table-responsive">
# <table class="table-info">
# <caption style="text-align: right;">
# <span class="set-color-gray set-color-graylight">* ข้อมูลเพื่อการศึกษาหรือใช้งานส่วนบุคคลเท่านั้น ไม่ใช่เพื่อประกอบการซื้อขายหลักทรัพย์</span><br/>
#         * ข้อมูลล่าสุด 28/05/2564 19:38:09
#     </caption>
# <thead>
# <tr>
# <th>ดัชนี</th>
# <th>ล่าสุด</th>
# <th>เปลี่ยนแปลง</th>
# <th>%เปลี่ยนแปลง</th>
# <th>สูงสุด</th>
# <th>ต่ำสุด</th>
# <th>ปริมาณ<br>('000 หุ้น)</br></th>
# <th>มูลค่า<br/>(ล้านบาท)</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td style="text-
# <ul>
# <li><a href="https://www.set.or.th/set/newsrelease.do?language=th&amp;country=TH">News Release</a></li>
# <li><a href="http://portal.set.or.th/tsd/eventcalendar.html?locale=th_TH">ปฏิทินกิจกรรม</a></li>
# <li><a href="https://www.set.or.th/set/activityList.do?language=th&amp;country=TH&amp;categoryId=2">ภาพกิจกรรมบจ./ผู้ออกหลักทรัพย์</a></li>
# <li><a href="https://www.set.or.th/set/iposhowcase.do?market=A&amp;language=th&amp;country=TH">กิจกรรมด้านผู้ออกหลักทรัพย์ </a></li>
# <li><a href="https://www.set.or.th/th/news/capital_market_innovation_awards/competition_p1.html">Capital Market Innovation Awards</a></li>
# <li><a href="https://www.set.or.th/th/news/cm_research_innovation/competition_p1.html">CM Research Innovation</a></li>
# <li><a href="https://www.set.or.th/th/news/thailand_focus/thailandfocus_p1.html">Thailand Focus</a></li>
# <li><a href="https://www.set.or.th/th/news/csr/csr_p1.html">ความรับผิดชอบต่อสังคม</a></li>
# </ul>
# </li>
# </ul>
# <div class="container padding-0">
# <div class="footer-col-3 footer-social">
# <div class="footer-body-menu">
# <ul class="footer-body-menu-ul">
# <li><i class="fa fa-globe"></i><a href="https://www.set.or.th/setresearch" target="_blank">SET Research</a></li>
# <li><i class="fa fa-cog"></i><a href="https://www.set.or.th/education/th/online_classroom/tool.html" target="_blank">เครื่องมือการเงินออนไลน์</a></li>
# <li><i class="fa fa-graduation-cap"></i><a href="https://www.set.or.th/education/th/online_classroom/index.html" target="_blank">ห้องเรียนออนไลน์ </a></li>
# <li><i class="fa fa-play-circle-o"></i><a href="https://www.youtube.com/user/setgroupofficial" target="_blank">VIDEO CENTER (เริ่มต้น/มือใหม่/มือโปร)</a></li>
# <li><i class="fa fa-facebook"></i><a href="https://www.facebook.com/set.or.th" target="_blank">www.facebook.com/set.or.th</a></li>
# <li><i class="fa fa-twitter"></i><a href="https://twitter.com/SET_Thailand" target="_blank">TWITTER @SET_Thailand</a></li>
# <li><i class="fa fa-youtube-play"></i><a href="https://www.youtube.com/user/setgroupofficial" target="_blank">Youtube.com/setgroupofficial</a></li>
# <li><i class="fa fa-rss"></i><a href="https://www.set.or.th/th/rss/rss_p1.html" target="_blank">RSS Feed</a></li>
# </ul>
# <ul class="footer-body-menu-ul">
# <li><a href="https://www.set.or.th/th/faqs/web_p1.html" target="_blank">ถาม - ตอบ</a>      | <a href="https://www.set.or.th/th/contact/contact.html" target="_blank">ติดต่อเรา</a><br/><a href="https://www.set.or.th/th/links/setgroup_website.html" target="_blank">เว็บไซต์น่าสนใจ</a>      | <a href="https://www.set.or.th/th/sitemap/sitemap_p1.html" target="_blank">แผนผังเว็บไซต์</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="container-fluid footer-bottom">
# <div class="container">
# <div class="row">
#     ตลาดหลักทรัพย์แห่งประเทศไทย | สงวนลิขสิทธิ์ <br/> เนื้อหาทั้งหมดบนเว็บไซต์นี้ มีขึ้นเพื่อวัตถุประสงค์ในการให้ข้อมูลและเพื่อการศึกษาเท่านั้น ตลาดหลักทรัพย์ฯ มิได้ให้การรับรองและขอปฏิเสธต่อความรับผิดใด ๆ ในเว็บไซต์นี้ <br/>
# <strong>
# <a href="https://www.set.or.th/th/terms-and-conditions.html" target="_blank">ข้อตกลงและเงื่อนไขการใช้งานเว็บไซต์</a>
#    | <a href="https://www.set.or.th/th/privacy-center.html" target="_blank">การคุ้มครองข้อมูลส่วนบุคคล</a>
#    | <a href="https://www.set.or.th/th/cookies_policy.html" target="_blank">นโยบายการใช้คุกกี้</a>
#    | <a href="https://www.set.or.th/th/thirdparty-terms.html" target="_blank">เงื่อนไขการใช้ข้อมูลของผู้ให้บริการรายอื่น</a>
# </strong>
# </div>
# </div>
# </div>
# <a class="gototop btn-set-rollover btn-set-upx2" href="#header" id="backToTopBtn"></a>
# <div class="truehit" id="showTruehit">
# <!-- BEGIN WEB STAT CODE---->
# <script language="javascript1.1"> page="th - prices - Securities Quotes - SET50";</script>
# <script type="text/javascript">
# 	  (function() {
# 		  var ga = document.createElement('script'); ga.type = 'text/javascript';
# 		  ga.async = true;
# 		  ga.src = "//lvs.truehits.in.th/dataa/c0002486.js";
# 		  var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(ga, s);
# 	  })();
# </script>
# <script>
# 	(function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# 		(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# 		m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
# 	})(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
# 	ga('create', 'UA-426404-1', 'auto');
# //	ga('send', 'pageview');
# </script>
# <!-- END WEB STAT CODE -->
# </div>
# </footer>
# <!-- End footer -->
# <script src="/scripts/socialmedia/facebook-module.js" type="text/javascript"></script>
# <!--[if lt IE 9]>
# <script type="text/javascript">
# 	//IE8 bind method hack
# 	if (!Function.prototype.bind) {
# 		Function.prototype.bind = function(oThis) {
# 			if ( typeof this !== 'function') {
# 				// closest thing possible to the ECMAScript 5
# 				// internal IsCallable function
# 				throw new TypeError('Function.prototype.bind - what is trying to be bound is not callable');
# 			}
#
# 			var aArgs = Array.prototype.slice.call(arguments, 1), fToBind = this, fNOP = function() {
# 			}, fBound = function() {
# 				return fToBind.apply(this instanceof fNOP && oThis ? this : oThis, aArgs.concat(Array.prototype.slice.call(arguments)));
# 			};
#
# 			fNOP.prototype = this.prototype;
# 			fBound.prototype = new fNOP();
#
# 			return fBound;
# 		};
# 	}
# </script>
# <![endif]-->
# <script src="//ajax.googleapis.com/ajax/libs/jquery/3.4.1/jquery.min.js"></script>
# <script>
# 	window.jQuery || document.write('<script src="/scripts/vendor/jquery.min.js"><\/script>')
# </script>
# <script src="/scripts/vendor/bootstrap.min.js"></script>
# <script src="/scripts/bootstrap-submenu.min.js"></script>
# <script type="text/javascript">
# 	$('.dropdown-submenu > a').submenupicker();
# </script>
# <script src="/scripts/bootstrap-hover-dropdown.min.js"></script>
# <script src="/scripts/bootstrap-tabcollapse.js"></script>
# <!-- GSAP -->
# <script src="/scripts/gsap/TweenLite.min.js"></script>
# <script src="/scripts/gsap/easing/EasePack.min.js"></script>
# <script src="/scripts/gsap/jquery.gsap.min.js"></script>
# <script src="/scripts/gsap/plugins/CSSPlugin.min.js"></script>
# <script src="/scripts/plugins.js"></script>
# <script src="/scripts/main.js"></script>
# <script src="/scripts/jQuery.XDomainRequest.js"></script>
# <script src="/scripts/orientationchange.js"></script>
# <!-- Manage Navigation -->
# <script language="javascript">
#         var menu_id = '402002';
#         var orderMenu = 'market';
#     </script>
# <script src="/scripts/menu/allLeftMenu-th.js"></script>
# <script src="/scripts/menu/genNavigation.js"></script>
# <script type="text/javascript">
#         $(document).ready(function () {
#             readmenuvar();
#             leftnav('accordion');
#             generateBreadCrumbs('breadcrumbs');
#
#             try {
#                 if (orderMenu !== undefined && orderMenu !== '') {
#                     window.dataLayer = window.dataLayer || [];
#                     dataLayer.push({
#                         "content_group": orderMenu
#                     });
#                 }
#             } catch (err) {
#             }
#         });
#     </script>
# <!-- End Navigation -->
# <link href="/styles/chat.css" rel="stylesheet"/>
# <link href="https://cubikachatuiuat.azurefd.net/cubikbot/plugins/cubik-bot-ui/dd-cubik-style.css" media="print" onload="this.media='all'" rel="stylesheet"/>
# <div class="select-chatbot-panel">
# <div class="live-chat-header">
# <span onclick="closeChatPanel()">X</span>
# </div>
# <div class="live-chat-body">
# <div class="live-btn">
# <div>
#                 SET Chatbot : ถามตอบเรื่องการลงทุน  24 ชั่วโมง
#             </div>
# <div class="chatbot-link-container">
# <button class="chatbot-link" onclick="openChatBot()">
#                     เลือก SET Chatbot กด
#                 </button>
# </div>
# </div>
# <div class="chatbot-btn">
# <div>
#                 สอบถามข้อมูลอื่นๆ กับเจ้าหน้าที่ ในวันทำการ เวลา 8.00 - 18.00 น.
#             </div>
# <div class="chatbot-link-container">
# <button class="chatbot-link" onclick="openLiveChat()">
#                     SET LiveChat กด
#                 </button>
# </div>
# </div>
# </div>
# </div>
# <div id="popup-outer-box">
# <div class="chat-media" id="popup-inner-box">
# <div class="chat-layout">
# <div class="chat-container">
# <button class="button-close" onclick="closeChatMedia()">
# <img class="icon-close" src="/images/chat/times.png"/>
# </button>
# <div class="chat-title">สวัสดี
#
#
#                     Friday
#
#             </div>
# <div class="chat-detail">
# <p class="chat-detail-text"></p>
# <a class="chat-detail-link" href="#" target="_blank"><button class="button-now">คลิกที่นี่</button></a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="chatbot-icon">
# <a href="javascript:openChatSelection()">
# <img src="/images/icon_chat_b.png">
# </img></a>
# </div>
# <div id="botGoesHere"></div>
# <script src="/scripts/chat.js"></script>
# <!-- Start of LiveChat (www.livechatinc.com) code -->
# <script type="text/javascript">
#     window.__lc = window.__lc || {};
#     window.__lc.license = 7604291;
#     (function() {
#         var lc = document.createElement('script'); lc.type = 'text/javascript'; lc.async = true;
#         lc.src = ('https:' == document.location.protocol ? 'https://' : 'http://') + 'cdn.livechatinc.com/tracking.js';
#         var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(lc, s);
#     })();
#     window.__lc.visitor = {
#         name: '',
#         email: ''
#     };
# </script>
# <!-- End of LiveChat code -->
# <!-- Start DDLG Chat bot -->
# <script async="" src="https://cubikachatuiuat.azurefd.net/cubikbot/plugins/cubik-bot-ui/dd-cubik-chatbot-vanilla-v1.1-min.js?v=12"></script>
# <script>
#     $(document).ready(function() {
#         $('.chatbot-icon').show();
#     });
# </script>
# <div class="exit-page-modal" id="exitPageModal">
# <div class="modal-dialog">
# <div class="exit-page-modal-content">
# <div class="exit-page-modal-header text-center">
# <button aria-label="Close" class="close" onclick="closeModal();" type="button">
# <span aria-hidden="true">×</span>
# </button>
# </div>
# <div class="modal-body text-center">
# <div class="personalized-exit-page-banner-optimize" id="personalized-exit-page-banner-optimize">
# <a href="#" target="_blank"><img src="#"/></a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <script type="text/javascript">
#     function addEvent(obj, event, fn) {
#         if (obj.addEventListener) {
#             obj.addEventListener(event, fn, false);
#         } else if (obj.attachEvent) {
#             obj.attachEvent("on" + event, fn);
#         }
#     }
#
#     function setCookie(name, value, days, domain) {
#         var expires = "";
#         if (days) {
#             var date = new Date();
#             date.setTime(date.getTime() + (days * 24 * 60 * 60 * 1000));
#             expires = "; expires=" + date.toUTCString();
#         }
#         var _value = name + "=" + (value || "") + expires + "; path=/";
#         if (domain && domain !== "") {
#             _value += "; domain=" + domain;
#         }
#         document.cookie = _value;
#     }
#
#     function getCookie(name) {
#         var nameEQ = name + "=";
#         var ca = document.cookie.split(';');
#         for (var i = 0; i < ca.length; i++) {
#             var c = ca[i];
#             while (c.charAt(0) == ' ') c = c.substring(1, c.length);
#             if (c.indexOf(nameEQ) == 0) return c.substring(nameEQ.length, c.length);
#         }
#         return null;
#     }
#
#     function hideExitAd() {
#         setCookie("display-exit-ad", "false", 1, ".set.or.th");
#     }
#
#     // Open the Modal
#     function openModal() {
#         document.getElementById("exitPageModal").style.display = "block";
#     }
#
#     // Close the Modal
#     function closeModal() {
#         document.getElementById("exitPageModal").style.display = "none";
#     }
#
#     addEvent(document, 'mouseout', function (event) {
#         if (event.toElement == null && event.relatedTarget == null) {
#             console.log('display-exit-ad = ' + getCookie('display-exit-ad'));
#             var display = getCookie("display-exit-ad");
#             if (display === "true") {
#                 openModal();
#             }
#             hideExitAd();
#         }
#     });
#
#     hideExitAd();
#
# </script>
# <style>
#     /* The Modal (background) */
#     .exit-page-modal {
#         position: fixed;
#         top: 0;
#         left: 0;
#         z-index: 1050;
#         display: none;
#         width: 100%;
#         height: 100%;
#         overflow: hidden;
#         outline: 0;
#         background-color: rgba(0, 0, 0, 0.5);
#     }
#     #exitPageModal .modal-dialog {
#         max-width: 340px;
#         margin-top: 10%;
#     }
#
#     #exitPageModal .exit-page-modal-content {
#         position: relative;
#         display: flex;
#         flex-direction: column;
#         width: 100%;
#         pointer-events: auto;
#         background-color: transparent;
#         background-clip: padding-box;
#         border: 0;
#         border-radius: .3rem;
#         outline: 0;
#     }
#
#     #exitPageModal .modal-body {
#         color: #242424;
#         padding: 0;
#     }
#     #exitPageModal .exit-page-modal-header{
#         padding-bottom: 0;
#         border: 0;
#         height: 45px;
#         background-color: transparent;
#     }
#
#     /* The Close Button */
#     #exitPageModal .close {
#         color: #fff;
#         position: absolute;
#         top: 5px;
#         right: 5px;
#         text-decoration: none;
#         cursor: pointer;
#         font-family: "DB Helvethaica X";
#         font-size: 40px;
#     }
#
# </style>
# </div>
# <!-- End Bottom Zone -->
# </body>
# </html>
# </html>

# %%
stat_table = html_page.find_all('table')

# %%
df = pd.read_html(str(stat_table))

# %%
df[2]
# Out:
#    หลักทรัพย์ เครื่องหมาย    เปิด  สูงสุด  ต่ำสุด  ล่าสุด เปลี่ยนแปลง  \
# 0      ADVANC         NaN  169.50  170.50  169.00  169.00       +1.00
# 1         AOT         NaN   63.00   63.50   62.25   62.25       -0.75
# 2         AWC         NaN    4.84    4.90    4.76    4.80       -0.04
# 3         BAM         NaN   18.80   19.00   18.60   18.60       -0.20
# 4         BBL         NaN  115.00  116.00  114.50  114.50       -0.50
# 5        BDMS         NaN   21.60   21.70   21.40   21.50           -
# 6         BEM         NaN    8.00    8.15    7.90    8.05       +0.10
# 7       BGRIM         NaN   44.50   44.50   43.50   43.75       -0.75
# 8          BH         NaN  131.00  132.50  131.00  131.00       -0.50
# 9         BJC         NaN   34.75   35.50   34.25   34.50       -0.25
# 10        BTS         NaN    9.10    9.15    8.90    9.00           -
# 11        CBG         NaN  130.00  135.00  130.00  131.50       +3.50
# 12       COM7         NaN   74.50   77.00   73.75   74.25           -
# 13      CPALL         NaN   61.25   61.25   60.25   60.75           -
# 14        CPF         NaN   27.50   27.75   27.00   27.25       -0.25
# 15        CPN         NaN   51.00   51.50   50.25   50.50           -
# 16        CRC         NaN   33.00   33.75   33.00   33.25       +0.25
# 17      DELTA         NaN  544.00  554.00  542.00  548.00       +4.00
# 18       DTAC         NaN   31.00   31.50   30.75   31.00       +0.25
# 19         EA         NaN   61.50   61.75   59.25   59.50       -2.00
# 20       EGCO         NaN  174.50  175.50  173.00  174.00           -
# 21     GLOBAL         NaN   21.30   21.50   20.80   21.00       -0.30
# 22       GPSC         NaN   72.50   72.75   71.50   72.00       -0.75
# 23       GULF         NaN   34.00   34.00   33.50   33.75       -0.25
# 24      HMPRO         NaN   14.10   14.20   13.80   13.80       -0.20
# 25     INTUCH         NaN   64.25   64.50   64.00   64.00           -
# 26        IVL          XD   46.00   46.25   45.25   45.50           -
# 27      KBANK         NaN  123.00  123.00  119.50  119.50       -2.00
# 28        KTB         NaN   10.90   11.00   10.80   10.80           -
# 29        KTC         NaN   74.25   75.00   71.25   73.25       -0.25
# 30         LH         NaN    8.05    8.10    7.95    8.00       -0.05
# 31       MINT         NaN   32.25   32.50   31.50   31.50       -0.50
# 32        MTC         NaN   62.00   62.50   61.25   61.50       -0.25
# 33         OR         NaN   30.25   30.75   30.00   30.25       +0.25
# 34        OSP         NaN   36.75   37.00   36.50   36.75       +0.25
# 35        PTT         NaN   39.25   39.50   39.00   39.25       +0.50
# 36      PTTEP         NaN  118.00  119.00  117.50  117.50       +0.50
# 37      PTTGC         NaN   63.25   63.50   62.50   63.00       +0.25
# 38      RATCH         NaN   51.75   52.00   50.75   50.75       -1.00
# 39      SAWAD         NaN   76.75   77.00   74.50   75.25       -0.25
# 40        SCB         NaN  103.50  103.50  101.00  102.00       -1.00
# 41        SCC         NaN  442.00  446.00  440.00  442.00       +2.00
# 42       SCGP         NaN   55.75   57.00   55.00   55.50           -
# 43      TISCO         NaN   90.25   90.50   89.00   89.50       -0.75
# 44        TOA         NaN   38.00   38.50   36.75   37.25       -0.75
# 45        TOP         NaN   57.25   59.75   57.25   59.25       +2.75
# 46       TRUE         NaN    3.16    3.18    3.12    3.14       -0.02
# 47        TTB         NaN    1.13    1.14    1.12    1.12       -0.01
# 48         TU         NaN   18.10   18.20   17.60   17.70       -0.30
# 49        VGI         NaN    6.30    6.35    6.10    6.20       -0.05
#
#    %เปลี่ยนแปลง  เสนอซื้อ  เสนอขาย  ปริมาณ(หุ้น)  มูลค่า('000 บาท)
# 0         +0.60    169.00   169.50       4386457         743477.50
# 1         -1.19     62.25    62.50      38939504        2448369.89
# 2         -0.83      4.78     4.80      63361422         305891.00
# 3         -1.06     18.60    18.70      14509626         271570.92
# 4         -0.43    114.50   115.00       6081141         701509.21
# 5             -     21.50    21.60      19662449         423413.35
# 6         +1.26      8.05     8.10     100841585         809966.02
# 7         -1.69     43.50    43.75      13262252         580794.29
# 8         -0.38    131.00   131.50        611293          80407.10
# 9         -0.72     34.50    34.75       4036707         140628.99
# 10            -      9.00     9.05      81406751         734573.82
# 11        +2.73    131.50   132.00      21636929        2869026.38
# 12            -     74.00    74.25      10835276         815842.12
# 13            -     60.50    60.75      30733864        1866216.17
# 14        -0.91     27.25    27.50      52107607        1425363.03
# 15            -     50.50    50.75       9441954         479047.17
# 16        +0.76     33.25    33.50      12332212         412624.60
# 17        +0.74    546.00   548.00        892995         490249.77
# 18        +0.81     31.00    31.25      14083298         437321.54
# 19        -3.25     59.50    59.75      10694364         643911.55
# 20            -    173.50   174.00       1116628         194537.29
# 21        -1.41     20.90    21.00      17982486         380545.90
# 22        -1.03     72.00    72.25       9636751         694750.98
# 23        -0.74     33.75    34.00       8227003         278005.92
# 24        -1.43     13.80    13.90      20906759         291318.17
# 25            -     64.00    64.25       8518879         547186.72
# 26            -     45.25    45.50      11200030         511295.17
# 27        -1.65    119.50   120.00      44970553        5458824.46
# 28            -     10.80    10.90      13647540         148519.84
# 29        -0.34     73.25    73.50      72213244        5287675.05
# 30        -0.62      8.00     8.05      49641650         398433.62
# 31        -1.56     31.50    31.75      10170603         323930.53
# 32        -0.40     61.50    61.75       5910498         364047.50
# 33        +0.83     30.00    30.25      43283109        1313949.52
# 34        +0.68     36.75    37.00       8873556         325911.30
# 35        +1.29     39.00    39.25      47161623        1851538.52
# 36        +0.43    117.50   118.00       5241077         619611.95
# 37        +0.40     62.75    63.00      12957720         817550.66
# 38        -1.93     50.75    51.00       6050658         310037.76
# 39        -0.33     75.00    75.25      11984197         906496.56
# 40        -0.97    101.50   102.00       9999428        1022939.38
# 41        +0.45    442.00   444.00       1814325         803672.36
# 42            -     55.50    55.75      27040805        1515054.66
# 43        -0.83     89.25    89.50       3893599         349265.51
# 44        -1.97     37.25    37.50       6156268         231538.94
# 45        +4.87     59.00    59.25      19928338        1174018.89
# 46        -0.63      3.12     3.14      34554167         108851.80
# 47        -0.88      1.12     1.13     281131954         317547.16
# 48        -1.67     17.70    17.80      30415260         541778.78
# 49        -0.80      6.15     6.20      41213698         256521.51

# %%
df[2].to_excel("set50.xlsx")
